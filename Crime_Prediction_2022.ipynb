# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_crime1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Crime_prediction/crime_state_name.csv')
data_crime1
# Out:
#                  STATE  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0       andhra pradesh  2001    2602               1555
# 1    arunachal pradesh  2001      83                 53
# 2                assam  2001    1356                481
# 3                bihar  2001    3643               3419
# 4         chhattisgarh  2001     880                529
# ..                 ...   ...     ...                ...
# 403         chandigarh  2012      21                 44
# 404       d & n haveli  2012       7                  2
# 405        daman & diu  2012       3                  5
# 406        lakshadweep  2012       0                  0
# 407         puducherry  2012      29                 27
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                          136   871               0
# 1                                            3    33               0
# 2                                           40   817               0
# ...

# %%
data_murder = data_crime1[data_crime1['STATE']=='karnataka']
data_murder
# Out:
#          STATE  YEAR  MURDER  ATTEMPT TO MURDER  \
# 11   karnataka  2001    1626               1475
# 45   karnataka  2002    1627               1576
# 79   karnataka  2003    1506               1241
# 113  karnataka  2004    1519               1387
# 147  karnataka  2005    1609               1406
# 181  karnataka  2006    1627               1484
# 215  karnataka  2007    1538               1251
# 249  karnataka  2008    1698               1475
# 283  karnataka  2009    1702               1607
# 317  karnataka  2010    1805               1850
# 351  karnataka  2011    1820               1837
# 385  karnataka  2012    1860               1923
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 11                                          74   293               0
# 45                                          55   292               0
# 79                                          58   321               0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np


plt.scatter(x =data_murder.YEAR , y =data_murder.MURDER , marker='o');
plt.xlabel('YEAR')
plt.ylabel('MURDER')
plt.show()

import matplotlib.pyplot as plt
from scipy import stats

x =data_murder.YEAR
y =data_murder.MURDER
slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas
from sklearn import linear_model

X = data_murder[['YEAR']]
y = data_murder['MURDER']

regr = linear_model.LinearRegression()
regr.fit(X, y)

data_2001 = regr.predict([[2001]])
print("Murder in 2001 were for ID:",y.head(1))
print("Predicted Model Murder in 2001",data_2001)
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
y_pred = regr.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(3)
print(df1)
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Murder in 2001 were for ID: 11    1626
# Name: MURDER, dtype: int64
# Predicted Model Murder in 2001 [1517.24358974]
#      Actual    Predicted
# 215    1538  1674.523310
# 385    1860  1805.589744
# 147    1609  1622.096737

# %%
#Now we apply Linear Regression for all states and in 30 different crimes and get predicted value for year 2022 wrt to their states and crime

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas
from sklearn import linear_model
for m in ['andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chhattisgarh', 'goa', 'gujarat', 'haryana','himachal pradesh','jammu & kashmir','jharkhand','karnataka', 'kerala', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya',
'mizoram', 'nagaland', 'odisha', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu',
'tripura', 'uttar pradesh', 'uttarakhand', 'west bengal', 'a & n islands',
'chandigarh', 'd & n haveli', 'daman & diu','lakshadweep','puducherry']:
    for n in range(1):
        data_murder =  data_crime1[data_crime1['STATE']==m]
        for p in ['MURDER',	'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE', 'OTHER RAPE',	'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY', 	'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT' , 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES' , 'CAUSING DEATH BY NEGLIGENCE']:
            for q in range(1):
                r = data_murder.loc[:,p]
                s = data_murder[['YEAR']]
                t = r
                regr = linear_model.LinearRegression()
                regr.fit(s,r)
                data_pred = regr.predict([[2022]])
                data_list = data_pred.tolist()
                data_list_round = []
                for num in data_list:
                    data_list_round.append(round(num))
                    print(data_list_round)
data_2022 = pd.DataFrame(data_list_round) 
print(data_2022)
# Out:
# [2754]
# [2656]
# [168]
# [1876]
# [0]
# [1876]
# [2990]
# [2435]
# [555]
# [16]
# [546]
# [8687]
# [36615]
# [13864]
# [22751]
# [1475]
# [1372]
# [13880]
# [404]
# [1081]
# [68855]
# [720]
# [6334]
# [6078]
# [20200]
# [-6]
# [21187]
# [62]
# [18]
# [0]
# [64]
# [0]
# [64]
# [90]
# [55]
# [36]
# [3]
# [50]
# [156]
# [432]
# [210]
# [222]
# [50]
# [81]
# [123]
# [0]
# [48]
# [447]
# [1]
# [67]
# [2]
# [28]
# [0]
# [242]
# [1406]
# [566]
# [53]
# [2645]
# [2]
# [2643]
# [5699]
# [4943]
# [756]
# [-12]
# [982]
# [4749]
# [12498]
# [3896]
# [8602]
# [2886]
# [1661]
# [2348]
# [95]
# [2050]
# [7536]
# [250]
# [2183]
# [13]
# [10353]
# [3]
# [3659]
# [2704]
# [4240]
# [328]
# [911]
# [0]
# [911]
# [6084]
# [5827]
# [258]
# [-382]
# [102]
# [4196]
# [24089]
# [9590]
# [14499]
# [10655]
# [1860]
# [5415]
# [28]
# [934]
# [48133]
# [1849]
# [503]
# [32]
# [4085]
# [-44]
# [8765]
# [1382]
# [972]
# [7]
# [1103]
# [0]
# [1103]
# [660]
# [498]
# [162]
# [57]
# [691]
# [3339]
# [6964]
# [4013]
# ...

# %%
# After getting data points through regression for year 2022, data is cleaned and processed further for clustering and analysis , crime_all_2022 is the cleaned data after regression.

# %%
import pandas as pd
data_crime2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Crime_prediction/crime_all_2022.csv')
data_crime2
# Out:
#                STATES  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0      andhra pradesh  2022    2754               2656
# 1   arunachal pradesh  2022      62                 18
# 2               assam  2022    1406                566
# 3               bihar  2022    2704               4240
# 4        chhattisgarh  2022    1382                972
# 5                 goa  2022      59                 34
# 6             gujarat  2022     852                385
# 7             haryana  2022    1343               1294
# 8    himachal pradesh  2022     132                 33
# 9     jammu & kashmir  2022     973                489
# 10          jharkhand  2022    1980                859
# 11          karnataka  2022    2068               2226
# 12             kerala  2022     240                343
# 13     madhya pradesh  2022    2451               1697
# 14        maharashtra  2022    2687               2809
# 15            manipur  2022       6                616
# ...

# %%
# Now In the data the states are converted to numerical for ease of plotting the data and avoid overlapping of X-axix in colab and clustering.

# %%
data_state = data_crime2

STATES = {'andhra pradesh':1, 'arunachal pradesh':2, 'assam':3, 'bihar':4, 'chhattisgarh':5, 'goa':6, 'gujarat':7, 'haryana':8,'himachal pradesh':9,'jammu & kashmir':10,'jharkhand':11,'karnataka':12, 'kerala':13, 'madhya pradesh':14, 'maharashtra':15, 'manipur':16, 'meghalaya':17,
'mizoram':18, 'nagaland':19, 'odisha':20, 'punjab':21, 'rajasthan':22, 'sikkim':23, 'tamil nadu':24,
 'tripura':25, 'uttar pradesh':26, 'uttarakhand':27, 'west bengal':28, 'a & n islands':29,
'chandigarh':30, 'd & n haveli':31, 'daman & diu':32,'lakshadweep':33,'puducherry':34
}
  
data_state.STATES = [STATES[item] for item in data_state.STATES]
data_state
# Out:
#     STATES  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0        1  2022    2754               2656
# 1        2  2022      62                 18
# 2        3  2022    1406                566
# 3        4  2022    2704               4240
# 4        5  2022    1382                972
# 5        6  2022      59                 34
# 6        7  2022     852                385
# 7        8  2022    1343               1294
# 8        9  2022     132                 33
# 9       10  2022     973                489
# 10      11  2022    1980                859
# 11      12  2022    2068               2226
# 12      13  2022     240                343
# 13      14  2022    2451               1697
# 14      15  2022    2687               2809
# 15      16  2022       6                616
# 16      17  2022     111                 59
# 17      18  2022      34                 17
# 18      19  2022      29                 49
# 19      20  2022    1916               1994
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.scatter(x =data_state.STATES , y =data_state.MURDER , color = 'green')
plt.xlabel('STATE')
plt.ylabel('MURDER')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML
import base64
sns.set()
from sklearn.cluster import KMeans
for p in ['MURDER',	'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'OTHER RAPE',	'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY', 	'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT' , 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES' , 'CAUSING DEATH BY NEGLIGENCE']:
  for q in range(1):
    k = data_state.loc[:,['STATES',p]]
    kmean = KMeans(3)
    kmean.fit(k)
    cluster = k.copy()
    cluster['cluster_predict'] = kmean.fit_predict(k)
    plt.scatter(cluster['STATES'] ,cluster[p],c=cluster['cluster_predict'],cmap='brg')
    plt.xlabel('STATES')
    plt.ylabel(p)
    plt.show()

    fig = plt.figure(figsize = (10, 5))
 
    plt.bar(cluster.STATES, cluster[p], color ='green',
        width = 0.5)
 
    plt.xlabel("State")
    plt.ylabel(p)
    plt.title("Crime vs State")
    plt.show()

# %%
# Now printing the clustered data for processing and displaying its geolocation below.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
for p in ['MURDER',	'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'OTHER RAPE',	'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY', 	'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT' , 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES' , 'CAUSING DEATH BY NEGLIGENCE']:
  for q in range(1):
    k = data_state.loc[:,['STATES',p]]
    kmean = KMeans(3)
    kmean.fit(k)
    cluster = k.copy()
    cluster['cluster_predict'] = kmean.fit_predict(k)
    data_2020 = cluster
    print(data_2020)
# Out:
#     STATES  MURDER  cluster_predict
# 0        1    2754                1
# 1        2      62                2
# 2        3    1406                0
# 3        4    2704                1
# 4        5    1382                0
# 5        6      59                2
# 6        7     852                0
# 7        8    1343                0
# 8        9     132                2
# 9       10     973                0
# 10      11    1980                1
# 11      12    2068                1
# 12      13     240                2
# 13      14    2451                1
# 14      15    2687                1
# 15      16       6                2
# 16      17     111                2
# 17      18      34                2
# 18      19      29                2
# 19      20    1916                1
# 20      21    1008                0
# 21      22    1640                0
# 22      23       9                2
# 23      24    2178                1
# 24      25      31                2
# ...

# %%
#Google Outreach Maps are used for geolocation display

# %%
# %%HTML
# <div>
# <iframe src="https://www.google.com/maps/d/u/0/embed?mid=1kROKer-V6U92-0R1HPON89OXLCwANB0&ehbc=2E312F" width="1300" height="800"></iframe>
# </div>
# Out:
# <div>
# <iframe src="https://www.google.com/maps/d/u/0/embed?mid=1kROKer-V6U92-0R1HPON89OXLCwANB0&ehbc=2E312F" width="1300" height="800"></iframe>
# </div>
