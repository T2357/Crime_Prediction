# %%
import pandas as pd
data_crime = pd.read_csv('F:\Crime rate prediction\Working in colab\crime_2022.csv')
data_crime
# Out:
#                 STATE  YEAR  MURDER  RAPE  ARSON  THEFT
# 0      andhra pradesh  2022    2754  1876   1081  36615
# 1   arunachal pradesh  2022      62    64     48    432
# 2               assam  2022    1406  2645   2050  12498
# 3               bihar  2022    2704   911    934  24089
# 4        chhattisgarh  2022    1382  1103    460   6964
# 5                 goa  2022      59    69     41   1504
# 6             gujarat  2022     852   646    565  17766
# 7             haryana  2022    1343  1096    191  29835
# 8    himachal pradesh  2022     132   227    117   1357
# 9     jammu & kashmir  2022     973   379     42   2975
# 10          jharkhand  2022    1980   914    153  10865
# 11          karnataka  2022    2068   973    214  26467
# 12             kerala  2022     240  1326    352   3840
# 13     madhya pradesh  2022    2451  3793    544  25826
# 14        maharashtra  2022    2687  2140   1260  67466
# 15            manipur  2022       6    84    103   1183
# ...

# %%
data_state = data_crime

STATE = {'andhra pradesh':1, 'arunachal pradesh':2, 'assam':3, 'bihar':4, 'chhattisgarh':5, 'goa':6, 'gujarat':7, 'haryana':8,'himachal pradesh':9,'jammu & kashmir':10,'jharkhand':11,'karnataka':12, 'kerala':13, 'madhya pradesh':14, 'maharashtra':15, 'manipur':16, 'meghalaya':17,
'mizoram':18, 'nagaland':19, 'odisha':20, 'punjab':21, 'rajasthan':22, 'sikkim':23, 'tamil nadu':24,
 'tripura':25, 'uttar pradesh':26, 'uttarakhand':27, 'west bengal':28, 'a & n islands':29,
'chandigarh':30, 'd & n haveli':31, 'daman & diu':32,'lakshadweep':33,'puducherry':34
}
  
data_state.STATE = [STATE[item] for item in data_state.STATE]
data_state
# Out:
#     STATE  YEAR  MURDER  RAPE  ARSON  THEFT
# 0       1  2022    2754  1876   1081  36615
# 1       2  2022      62    64     48    432
# 2       3  2022    1406  2645   2050  12498
# 3       4  2022    2704   911    934  24089
# 4       5  2022    1382  1103    460   6964
# 5       6  2022      59    69     41   1504
# 6       7  2022     852   646    565  17766
# 7       8  2022    1343  1096    191  29835
# 8       9  2022     132   227    117   1357
# 9      10  2022     973   379     42   2975
# 10     11  2022    1980   914    153  10865
# 11     12  2022    2068   973    214  26467
# 12     13  2022     240  1326    352   3840
# 13     14  2022    2451  3793    544  25826
# 14     15  2022    2687  2140   1260  67466
# 15     16  2022       6    84    103   1183
# 16     17  2022     111   274     81    994
# 17     18  2022      34   138      9    382
# 18     19  2022      29    25      7    542
# 19     20  2022    1916  1787    611  12259
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.scatter(x =data_state.STATE , y =data_state.MURDER , color = 'red')
plt.xlabel('STATE')
plt.ylabel('MURDER')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
plt.scatter(x =data_state.STATE , y =data_state.RAPE , color = 'blue')
plt.xlabel('STATE')
plt.ylabel('RAPE')
plt.show()

# %%
# %matplotlib inline
plt.scatter(x =data_state.STATE , y =data_state.ARSON , color = 'indigo')
plt.xlabel('STATE')
plt.ylabel('ARSON')
plt.show()

# %%
# %matplotlib inline
plt.scatter(x =data_state.STATE , y =data_state.THEFT , color = 'orange')
plt.xlabel('STATE')
plt.ylabel('THEFT')
plt.show()

# %%
data_points = data_state.loc[:,['STATE','MURDER']]
data_points['STATE'] = data_points['STATE'].astype('category')
data_points.dtypes
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.scatter(x =data_points.STATE , y =data_points.MURDER , color = 'blue')
plt.xlabel('STATE')
plt.ylabel('MURDER')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data_cluster = data_state.loc[:,['STATE','ARSON']]
print(data_cluster)
# Out:
#     STATE  ARSON
# 0       1   1081
# 1       2     48
# 2       3   2050
# 3       4    934
# 4       5    460
# 5       6     41
# 6       7    565
# 7       8    191
# 8       9    117
# 9      10     42
# 10     11    153
# 11     12    214
# 12     13    352
# 13     14    544
# 14     15   1260
# 15     16    103
# 16     17     81
# 17     18      9
# 18     19      7
# 19     20    611
# 20     21    119
# 21     22    186
# 22     23     25
# 23     24    406
# 24     25     71
# 25     26    103
# 26     27      3
# 27     28    686
# 28     29     14
# 29     30     13
# 30     31     14
# 31     32      8
# 32     33      3
# 33     34      1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.scatter(x =data_state.STATE , y =data_state.MURDER , color = 'red')
plt.xlabel('STATE')
plt.ylabel('ARSON')
plt.show()

# %%
X = data_cluster.copy()
X
# Out:
#     STATE  ARSON
# 0       1   1081
# 1       2     48
# 2       3   2050
# 3       4    934
# 4       5    460
# 5       6     41
# 6       7    565
# 7       8    191
# 8       9    117
# 9      10     42
# 10     11    153
# 11     12    214
# 12     13    352
# 13     14    544
# 14     15   1260
# 15     16    103
# 16     17     81
# 17     18      9
# 18     19      7
# 19     20    611
# 20     21    119
# 21     22    186
# 22     23     25
# 23     24    406
# 24     25     71
# 25     26    103
# 26     27      3
# 27     28    686
# 28     29     14
# 29     30     13
# 30     31     14
# 31     32      8
# 32     33      3
# 33     34      1

# %%
kmeans = KMeans(3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
clusters = X.copy()
clusters['cluster_pred'] = kmeans.fit_predict(X)

# %%
# %matplotlib notebook
plt.scatter(clusters['STATE'] ,clusters['ARSON'],c=clusters['cluster_pred'],cmap='brg')
plt.xlabel('STATE')
plt.ylabel('ARSON')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
for n in range(1):
    data_kmeans =  data_state[data_state['STATE']==m]
    for p in ['MURDER','RAPE','ARSON','THEFT']:
        for q in range(1):
            k = data_state.loc[:,['STATE',p]]
            kmean = KMeans(3)
            kmean.fit(k)
            cluster = k.copy()
            cluster['cluster_predict'] = kmean.fit_predict(k)
            plt.scatter(cluster['STATE'] ,cluster[p],c=cluster['cluster_predict'],cmap='brg')
            plt.xlabel('STATE')
            plt.ylabel(p)
            plt.show()
